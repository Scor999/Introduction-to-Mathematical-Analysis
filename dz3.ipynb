# %% [markdown]
# <a href="https://colab.research.google.com/github/Scor999/Introduction-to-Mathematical-Analysis/blob/main/dz3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### Практическое задание к уроку 4

# %% [markdown]
# 1. Предложить пример функции, не имеющей предела в нуле и в бесконечностях.
#
# $$f(x) = \sin{\left(x+\frac{1}{x}\right)}$$
#
#
#
# Предел функции может отсутствовать если значения функции в области определения\
# равны бесконечности\или\ имеют колебательный характер.
# Предел функции является обобщением понятия предела последовательности. Изначально под пределом функции
# f(x) в точке x понимали предел последовательности значений функции:
# ${\displaystyle f(x_{1}),f(x_{2}),f(x_{3}),\dots }$
# соответствующих последовательности элементов области определения функции
# ${\displaystyle x_{1},x_{2},x_{3}\dots }$, сходящейся к точке
# x. Если такой предел существует, то говорят, что функция сходится к указанному значению, иначе говорят, что функция расходится.
#
# Наиболее часто определение предела функции формулируют на языке окрестностей. То, что предел функции рассматривается только в точках, предельных для области определения функции, означает, что в любой окрестности данной точки существуют точки области определения. Это позволяет говорить о стремлении аргумента функции к данной точке. При этом предельная точка области определения не обязана принадлежать самой области определения: например, можно рассматривать предел функции на концах открытого интервала, на котором определена функция (сами концы интервала в область определения не входят).

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

sns.set(rc={'figure.figsize': (9, 3)})

# %%
np.seterr(divide='ignore')

x = np.arange(-100, 100, 0.5)
#y = np.sin(x + 1/x)
y = 1/x

plt.axhline(linewidth=1.0, color="black")
plt.axvline(linewidth=1.0, color="black")

plt.plot(x,y)
plt.show()

# %% [markdown]
# 2. Привести пример функции, не имеющей предела в точке, но определенной в ней.

# %% [markdown]
# $f(x) = sin(x)$
#
# $f(x) = (sin x) / x$
#
# Функция,
# $y=x^2$
# в точке х
# предела не имеет, т.к существующие правый и левый пределы этой функции в точке не равны между собой.

# %% [markdown]
# 3. Исследовать функцию $f(x) = x^3 - x^2$ по плану:
#
# a. Область задания и область значений.
# b. Нули функции и их кратность.
# c. Отрезки знакопостоянства.
# d. Интервалы монотонности.
# e. Четность функции.
# f. Ограниченность.
# g. Периодичность.

# %%
np.seterr(divide='ignore')

x = np.arange(-2, 3, 0.1)
y = x**3 - x**2

plt.axhline(linewidth=1.0, color="black")
plt.axvline(linewidth=1.0, color="black")
plt.axis('equal')

plt.plot(x,y)
plt.show()

# %% [markdown]
# a. Область задания и область значений.
#
# $(-\infty; +\infty)$

# %% [markdown]
# b. Нули функции и их кратность.
#
# 0; 1

# %% [markdown]
# c. Отрезки знакопостоянства.
#
# $(-\infty; 0): f(-2) = -12 < 0$
#
# $(0; 1): f(\frac{1}{3}) = -\frac{2}{27} < 0$
#
# $(1; +\infty): f(2) = 4 > 0$

# %% [markdown]
# d. Интервалы монотонности.
#
# $(-\infty; 0), (0; \frac{2}{3}), (\frac{2}{3}; +\infty)$
#
# $(-\infty; 0) - возрастает$
#
# $(0; \frac{2}{3}) - убывает$
#
# $(\frac{2}{3}; +\infty) - возрастает$

# %% [markdown]
# e. Четность функции.
#
# ни чётная и ни нечётная

# %% [markdown]
# f. Ограниченность.
#
# не ограничена

# %% [markdown]
# g. Периодичность.
#
# не является периодической

# %% [markdown]
# Найти пределы:

# %% [markdown]
# a. $\lim\limits_{x \to 0}\frac{3x^3-2x^2}{4x^2} = \left({\color{red}{\frac{0}{0}}}\right) = \lim\limits_{x \to 0}\frac{3x^3-2x^2}{4x^2} = \frac{3}{4}x^2 - \frac{1}{2} = \lim\limits_{x \to 0}\frac{3}{4}x^2 - \frac{1}{2} = - \frac{1}{2}$;

# %% [markdown]
# b. $\lim\limits_{x \to 0}\frac{\sqrt{1+x} -1}{\sqrt[3]{1+x}-1} = \left({\color{red}{\frac{0}{0}}}\right) = \lim\limits_{x \to 0}\frac{\sqrt{1+x} -1}{\sqrt[3]{1+x}-1} \bullet \frac{\sqrt{1+x} + 1}{\sqrt{1+x} + 1} \bullet \frac{\sqrt[3]{(1+x)^2} + \sqrt[3]{1+x} + 1}{\sqrt[3]{(1+x)^2} + \sqrt[3]{1+x} + 1} = \lim\limits_{x \to 0} \frac{1 + x - 1}{1 + x -1} \bullet \frac{\sqrt[3]{(1+x)^2} + \sqrt[3]{1+x} + 1}{\sqrt{1+x} + 1} = \lim\limits_{x \to 0}\frac{\sqrt[3]{(1+x)^2} + \sqrt[3]{1+x} + 1}{\sqrt{1+x} + 1} = \frac{1 + 1 + 1}{2} = \frac{3}{2} = 1\frac{1}{2}$;

# %% [markdown]
# c. $\lim\limits_{x \to \infty}\left(\frac{x+3}{x}\right)^{4x+1} = ({\color{red}{\frac{\infty}{\infty}}}) = \lim\limits_{x \to \infty}\left(1 + \frac{3}{x}\right)^{4x+1} = ({\color{red}{1^\infty}}) = \lim\limits_{x \to \infty}\left(1 + \frac{3}{x}\right)^{\frac{x}{3} \bullet \frac{3}{x} \bullet (4x+1) } = e^{\lim\limits_{x \to \infty}\frac{12x+1}{x}} = e^{12}$;

# %% [markdown]
# Тема “Теоремы о пределах”

# %% [markdown]
# Найти предел:

# %% [markdown]
# - A $\lim\limits_{x \to 0}\frac{\sin{(2x)}}{4x} = \left({\color{red}{\frac{0}{0}}}\right) = \lim\limits_{x \to 0}\frac{\sin{(2x)}}{2 \bullet 2x} = \frac{1}{2}$

# %% [markdown]
# - B $\lim\limits_{x \to 0}\frac{x}{\sin{x}} = \left({\color{red}{\frac{0}{0}}}\right) = 1$

# %% [markdown]
# - C
# $\lim\limits_{x \to 0}\frac{x}{\arcsin{x}} = \left({\color{red}{\frac{0}{0}}}\right) = 1$

# %% [markdown]
# - D. $\lim\limits_{x \to \infty}\left(\frac{4x+3}{4x-3} \right)^{6x} = ({\color{red}{\frac{\infty}{\infty}}}) = \lim\limits_{x \to \infty}\left(1 + \frac{6}{4x - 3}\right) ^{6x} = ({\color{red}{1^\infty}}) = \lim\limits_{x \to \infty}\left(1 + \frac{6}{4x - 3}\right) ^{\frac{4x - 3}{6} \bullet \frac{6}{4x - 3} \bullet 6x} = e^{\lim\limits_{x \to \infty} \frac{36x}{4x -3}} = e^{\frac{36}{4}} = e^9$

# %% [markdown]
# - E. $\lim\limits_{x \to \infty}\frac{\sin{x}+\ln{x}}{x} = \lim\limits_{x \to \infty}\left(\frac{\sin{x}}{x} + \frac{\ln{x}}{x}\right) = \lim\limits_{x \to \infty} \frac{\sin{x}}{x} + \lim\limits_{x \to \infty}\frac{\ln{x}}{x}$
#
# $\lim\limits_{x \to \infty} \frac{\sin{x}}{x} = \lim\limits_{x \to \infty} \left( \frac{-1}{x} \leq \frac{\sin{x}}{x} \leq \frac{1}{x} \right)$
#
# $\lim\limits_{x \to \infty} \frac{-1}{x} = \lim\limits_{x \to \infty} \frac{1}{x} = 0$
#
#
# $\lim\limits_{x \to \infty}\frac{\ln{x}}{x} = ({\color{red}{\frac{\infty}{\infty}}}) = \lim\limits_{x \to \infty} \frac{\frac{d}{dx}[\ln{x}]}{\frac{d}{dx}[x]} = \lim\limits_{x \to \infty} \frac{\frac{1}{x}}{1} = \frac{\lim\limits_{x \to \infty}\frac{1}{x}}{\lim\limits_{x \to \infty} 1} = \frac{0}{1} = 0$
#
# $\lim\limits_{x \to \infty}\frac{\ln{x}}{x} = ({\color{red}{\frac{\infty}{\infty}}}) = \lim\limits_{x \to \infty} \frac{\frac{d}{dx}[\ln{x}]}{\frac{d}{dx}[x]}$
#
#
# $\lim\limits_{x \to \infty} \frac{\frac{1}{x}}{1} = \frac{\lim\limits_{x \to \infty}\frac{1}{x}}{\lim\limits_{x \to \infty} 1} = \frac{0}{1} = 0$
#
#
# $\lim\limits_{x \to \infty} \frac{\sin{x}}{x} + \lim\limits_{x \to \infty}\frac{\ln{x}}{x} = 0 + 0 = 0$

# %% [markdown]
# - F. $\lim\limits_{x \to 0}\frac{\sin{x}+\ln{x}}{x} = \lim\limits_{x \to 0}\left(\frac{\sin{x}}{x} + \frac{\ln{x}}{x}\right) = \lim\limits_{x \to 0} \frac{\sin{x}}{x} + \lim\limits_{x \to 0}\frac{\ln{x}}{x}$
#
# $\lim\limits_{x \to 0} \frac{\sin{x}}{x} = \left({\color{red}{\frac{0}{0}}}\right) = 1$
#
# $\lim\limits_{x \to 0}\frac{\ln{x}}{x} = \varnothing$
#
# $\lim\limits_{x \to 0} \frac{\sin{x}}{x} + \lim\limits_{x \to 0}\frac{\ln{x}}{x} = 1 + \varnothing = \varnothing$
